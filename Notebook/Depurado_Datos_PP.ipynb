# %%
#--BASE--#
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import numpy as np
import datetime
import os
import datetime 

#--VISUALIZACIÓN--#
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

#--CONFIGURACIÓN--#
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.options.display.float_format = '{:.2f}'.format
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('../Clima/Precipitation/1_Alabama.csv')
df['State'] = 'Alabama'
df.to_csv('../Clima/Precipitation/1_Alabama.csv')

df = pd.read_csv('../Clima/Precipitation/2_Arizona.csv')
df['State'] = 'Arizona'
df.to_csv('../Clima/Precipitation/2_Arizona.csv')

df = pd.read_csv('../Clima/Precipitation/3_Arkansas.csv')
df['State'] = 'Arkansas'
df.to_csv('../Clima/Precipitation/3_Arkansas.csv')

df = pd.read_csv('../Clima/Precipitation/4_California.csv')
df['State'] = 'California'
df.to_csv('../Clima/Precipitation/4_California.csv')

df = pd.read_csv('../Clima/Precipitation/5_Colorado.csv')
df['State'] = 'Colorado'
df.to_csv('../Clima/Precipitation/5_Colorado.csv')

df = pd.read_csv('../Clima/Precipitation/6_Connecticut.csv')
df['State'] = 'Connecticut'
df.to_csv('../Clima/Precipitation/6_Connecticut.csv')

df = pd.read_csv('../Clima/Precipitation/7_Delaware.csv')
df['State'] = 'Delaware'
df.to_csv('../Clima/Precipitation/7_Delaware.csv')

df = pd.read_csv('../Clima/Precipitation/8_Florida.csv')
df['State'] = 'Florida'
df.to_csv('../Clima/Precipitation/8_Florida.csv')

df = pd.read_csv('../Clima/Precipitation/9_Georgia.csv')
df['State'] = 'Georgia'
df.to_csv('../Clima/Precipitation/9_Georgia.csv')

df = pd.read_csv('../Clima/Precipitation/10_Idaho.csv')
df['State'] = 'Idaho'
df.to_csv('../Clima/Precipitation/10_Idaho.csv')

df = pd.read_csv('../Clima/Precipitation/11_Illinois.csv')
df['State'] = 'Illinois'
df.to_csv('../Clima/Precipitation/11_Illinois.csv')

df = pd.read_csv('../Clima/Precipitation/12_Indiana.csv')
df['State'] = 'Indiana'
df.to_csv('../Clima/Precipitation/12_Indiana.csv')

df = pd.read_csv('../Clima/Precipitation/13_Iowa.csv')
df['State'] = 'Iowa'
df.to_csv('../Clima/Precipitation/13_Iowa.csv')

df = pd.read_csv('../Clima/Precipitation/14_Kansas.csv')
df['State'] = 'Kansas'
df.to_csv('../Clima/Precipitation/14_Kansas.csv')

df = pd.read_csv('../Clima/Precipitation/15_Kentucky.csv')
df['State'] = 'Kentucky'
df.to_csv('../Clima/Precipitation/15_Kentucky.csv')

df = pd.read_csv('../Clima/Precipitation/16_Louisiana.csv')
df['State'] = 'Louisiana'
df.to_csv('../Clima/Precipitation/16_Louisiana.csv')

df = pd.read_csv('../Clima/Precipitation/17_Maine.csv')
df['State'] = 'Maine'
df.to_csv('../Clima/Precipitation/17_Maine.csv')

df = pd.read_csv('../Clima/Precipitation/18_Maryland.csv')
df['State'] = 'Maryland'
df.to_csv('../Clima/Precipitation/18_Maryland.csv')

df = pd.read_csv('../Clima/Precipitation/19_Massachusetts.csv')
df['State'] = 'Massachusetts'
df.to_csv('../Clima/Precipitation/19_Massachusetts.csv')

df = pd.read_csv('../Clima/Precipitation/20_Michigan.csv')
df['State'] = 'Michigan'
df.to_csv('../Clima/Precipitation/20_Michigan.csv')

df = pd.read_csv('../Clima/Precipitation/21_Minnesota.csv')
df['State'] = 'Minnesota'
df.to_csv('../Clima/Precipitation/21_Minnesota.csv')

df = pd.read_csv('../Clima/Precipitation/22_Mississippi.csv')
df['State'] = 'Mississippi'
df.to_csv('../Clima/Precipitation/22_Mississippi.csv')

df = pd.read_csv('../Clima/Precipitation/23_Missouri.csv')
df['State'] = 'Missouri'
df.to_csv('../Clima/Precipitation/23_Missouri.csv')

df = pd.read_csv('../Clima/Precipitation/24_Montana.csv')
df['State'] = 'Montana'
df.to_csv('../Clima/Precipitation/24_Montana.csv')

df = pd.read_csv('../Clima/Precipitation/25_Nebraska.csv')
df['State'] = 'Nebraska'
df.to_csv('../Clima/Precipitation/25_Nebraska.csv')

df = pd.read_csv('../Clima/Precipitation/26_Nevada.csv')
df['State'] = 'Nevada'
df.to_csv('../Clima/Precipitation/26_Nevada.csv')

df = pd.read_csv('../Clima/Precipitation/27_New_Hampshire.csv')
df['State'] = 'New_Hampshire'
df.to_csv('../Clima/Precipitation/27_New_Hampshire.csv')

df = pd.read_csv('../Clima/Precipitation/28_New_Jersey.csv')
df['State'] = 'New_Jersey'
df.to_csv('../Clima/Precipitation/28_New_Jersey.csv')

df = pd.read_csv('../Clima/Precipitation/29_New_Mexico.csv')
df['State'] = 'New_Mexico'
df.to_csv('../Clima/Precipitation/29_New_Mexico.csv')

df = pd.read_csv('../Clima/Precipitation/30_New_York.csv')
df['State'] = 'New_York'
df.to_csv('../Clima/Precipitation/30_New_York.csv')

df = pd.read_csv('../Clima/Precipitation/31_North_Carolina.csv')
df['State'] = 'North_Carolina'
df.to_csv('../Clima/Precipitation/31_North_Carolina.csv')

df = pd.read_csv('../Clima/Precipitation/32_North_Dakota.csv')
df['State'] = 'North_Dakota'
df.to_csv('../Clima/Precipitation/32_North_Dakota.csv')

df = pd.read_csv('../Clima/Precipitation/33_Ohio.csv')
df['State'] = 'Ohio'
df.to_csv('../Clima/Precipitation/33_Ohio.csv')

df = pd.read_csv('../Clima/Precipitation/34_Oklahoma.csv')
df['State'] = 'Oklahoma'
df.to_csv('../Clima/Precipitation/34_Oklahoma.csv')

df = pd.read_csv('../Clima/Precipitation/35_Oregon.csv')
df['State'] = 'Oregon'
df.to_csv('../Clima/Precipitation/35_Oregon.csv')

df = pd.read_csv('../Clima/Precipitation/36_Pennsylvania.csv')
df['State'] = 'Pennsylvania'
df.to_csv('../Clima/Precipitation/36_Pennsylvania.csv')

df = pd.read_csv('../Clima/Precipitation/37_Rhode_Island.csv')
df['State'] = 'Rhode_Island'
df.to_csv('../Clima/Precipitation/37_Rhode_Island.csv')

df = pd.read_csv('../Clima/Precipitation/38_South_Carolina.csv')
df['State'] = 'South_Carolina'
df.to_csv('../Clima/Precipitation/38_South_Carolina.csv')

df = pd.read_csv('../Clima/Precipitation/39_South_Dakota.csv')
df['State'] = 'South_Dakota'
df.to_csv('../Clima/Precipitation/39_South_Dakota.csv')

df = pd.read_csv('../Clima/Precipitation/40_Tennessee.csv')
df['State'] = 'Tennessee'
df.to_csv('../Clima/Precipitation/40_Tennessee.csv')

df = pd.read_csv('../Clima/Precipitation/41_Texas.csv')
df['State'] = 'Texas'
df.to_csv('../Clima/Precipitation/41_Texas.csv')

df = pd.read_csv('../Clima/Precipitation/42_Utah.csv')
df['State'] = 'Utah'
df.to_csv('../Clima/Precipitation/42_Utah.csv')

df = pd.read_csv('../Clima/Precipitation/43_Vermont.csv')
df['State'] = 'Vermont'
df.to_csv('../Clima/Precipitation/43_Vermont.csv')

df = pd.read_csv('../Clima/Precipitation/44_Virginia.csv')
df['State'] = 'Virginia'
df.to_csv('../Clima/Precipitation/44_Virginia.csv')

df = pd.read_csv('../Clima/Precipitation/45_Washington.csv')
df['State'] = 'Washington'
df.to_csv('../Clima/Precipitation/45_Washington.csv')

df = pd.read_csv('../Clima/Precipitation/46_West_Virginia.csv')
df['State'] = 'West_Virginia'
df.to_csv('../Clima/Precipitation/46_West_Virginia.csv')

df = pd.read_csv('../Clima/Precipitation/47_Wisconsin.csv')
df['State'] = 'Wisconsin'
df.to_csv('../Clima/Precipitation/47_Wisconsin.csv')

df = pd.read_csv('../Clima/Precipitation/48_Wyoming.csv')
df['State'] = 'Wyoming'
df.to_csv('../Clima/Precipitation/48_Wyoming.csv')

df = pd.read_csv('../Clima/Precipitation/50_Alaska.csv')
df['State'] = 'Alaska'
df.to_csv('../Clima/Precipitation/50_Alaska.csv')

# %%
#leo los archivos de Tempreratura descargados por webScraping y los concateno
path = '../Clima/Precipitation/'
files = [os.path.join(path, file) for file in os.listdir(path) if ".csv" in file]

df = pd.concat(map(pd.read_csv, files))

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'Unnamed: 0.1.1', 'date', 'January',
#        'February', 'March', 'April', 'May', 'June', 'July', 'August',
#        'September', 'October', 'November', 'December', 'State'],
#       dtype='object')

# %%
df.drop(['Unnamed: 0','Unnamed: 0.1', 'Unnamed: 0.1.1'], axis = 1, inplace = True)

# %%
col = df.pop('State')
df.insert(loc= 0 , column= 'State', value= col)

# %%
df
# Out:
#              State  date  January  February  March  April   May  June  July  \
# 0         Kentucky  1950    12.61      5.14   3.78   2.96  6.00  6.41  6.30
# 1         Kentucky  1951     7.43      4.64   4.94   3.37  2.58  5.00  3.07
# 2         Kentucky  1952     5.51      2.68   7.31   2.65  4.03  2.66  2.73
# 3         Kentucky  1953     4.73      2.19   5.49   3.94  5.46  3.38  3.52
# 4         Kentucky  1954     5.50      2.23   2.69   3.72  3.13  2.86  3.19
# 5         Kentucky  1955     1.76      7.19   7.41   3.61  4.26  4.31  4.06
# 6         Kentucky  1956     3.91      8.92   5.05   4.92  3.66  3.62  6.00
# 7         Kentucky  1957     6.42      4.33   2.37   5.52  5.55  5.31  3.08
# 8         Kentucky  1958     2.55      2.31   3.54   5.51  4.67  4.26  7.89
# 9         Kentucky  1959     4.82      2.97   2.62   3.00  4.53  2.89  4.80
# 10        Kentucky  1960     2.84      4.01   3.03   1.83  3.51  7.12  3.54
# ...

# %%
df.to_csv('../Clima/Precipitation/TOTAL_STATES_PP.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2631/2135946884.py in <module>
# ----> 1 df.to_csv('../Clima/Precipitation/TOTAL_STATES_PP.csv')
#
# NameError: name 'df' is not defined
