# %%
#--BASE--#
# %matplotlib inline
import pandas as pd
import seaborn as sns
import warnings
import numpy as np
import datetime
import os
import warnings
from datetime import timedelta
import funciones
from phik import phik_matrix
from minepy import MINE

#--VISUALIZACIÓN--#
import matplotlib as mpl
import plotly.graph_objects as go
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.figure_factory as ff
from plotly.subplots import make_subplots

#--CONFIGURACIÓN--#
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)
pd.options.display.float_format = '{:.2f}'.format
warnings.filterwarnings('ignore')

# %%
pd.DataFrame({
    'Idaho' : ['Units: Degrees Fahrenheit', 'Base Period: 1901-2000', 'Missing: -99', 'Date', 195001, 195101, 195101, 195301, 195401, 195501, 195601, '...'],
    'Maximum Temperature':['NaN','NaN','NaN', 'Value', 52.4, 62.9, 40.0, 50.6, 42.7, 56.8, 53.5,'...'],
    'May':['NaN','NaN','NaN', 'May', 11.4, 11.4, 5.0, 5.6, 1.7, -0.2, -1.5, '...']
})
# Out:
#                         Idaho Maximum Temperature   May
# 0   Units: Degrees Fahrenheit                 NaN   NaN
# 1      Base Period: 1901-2000                 NaN   NaN
# 2                Missing: -99                 NaN   NaN
# 3                        Date               Value   May
# 4                      195001               52.40 11.40
# 5                      195101               62.90 11.40
# 6                      195101               40.00  5.00
# 7                      195301               50.60  5.60
# 8                      195401               42.70  1.70
# 9                      195501               56.80 -0.20
# 10                     195601               53.50 -1.50
# 11                        ...                 ...   ...

# %%
pd.DataFrame({
    'date' : [1950, 1951, 1951, 1953, 1954, 1955, 1956, '...'],
    'Maximum Temperature':[52.4, 62.9, 40.0, 50.6, 42.7, 56.8, 53.5,'...'],
    'month':['May', 'May', 'May', 'May', 'May', 'May', 'May', '...'],
    'state':['Idaho', 'Idaho', 'Idaho', 'Idaho', 'Idaho', 'Idaho', 'Idaho', '...']
})
# Out:
#    date Maximum Temperature    month    state
# 0  1950               68.40  January  Alabama
# 1  1951               58.90  January  Alabama
# 2  1951               63.00  January  Alabama
# 3  1953               60.60  January  Alabama
# 4  1954               58.70  January  Alabama
# 5  1955               54.80  January  Alabama
# 6  1956               53.50  January  Alabama
# 7   ...                 ...      ...      ...

# %%
state = pd.read_csv('../DATOS/Clima/Maximum temperature/1950-2021.csv')
state
# Out:
#                       Alabama  Maximum Temperature  January
# 0   Units: Degrees Fahrenheit                  NaN      NaN
# 1      Base Period: 1901-2000                  NaN      NaN
# 2                Missing: -99                  NaN      NaN
# 3                        Date                Value  Anomaly
# 4                      195001                 68.4     12.4
# 5                      195101                 58.9      2.9
# 6                      195201                 63.0      7.0
# 7                      195301                 60.6      4.6
# 8                      195401                 58.7      2.7
# 9                      195501                 54.8     -1.2
# 10                     195601                 53.5     -2.5
# 11                     195701                 58.8      2.8
# 12                     195801                 50.2     -5.8
# 13                     195901                 55.8     -0.2
# 14                     196001                 53.6     -2.4
# ...

# %%
lista =[]
for i in state:
    state = state.columns[0]
    lista.append(state)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11224\2966722388.py in <module>
#       1 lista =[]
#       2 for i in state:
# ----> 3     state = state.columns[0]
#       4     lista.append(state)
#       5
#
# AttributeError: 'str' object has no attribute 'columns'

# %%
state[state] = state

#state[month] =
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11224\4017640602.py in <module>
# ----> 1 state[state] = state
#       2
#       3 #state[month] =
#
# TypeError: 'str' object does not support item assignment
